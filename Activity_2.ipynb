# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahdirecto/CPE-201L-DSA-2-A/blob/main/Activity_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def traverse_array(arr):
     """Function to traverse and print all elements in the array"""
     print("Traversing the array:")
     for i, element in enumerate(arr):
        print(f"Index {i}: {element}")

def reverse_array(arr):
     """Function to reverse and print all elements in the array"""
     print("Reversing the array:")
     reversed_arr = arr[::-1]
     print(reversed_arr)
     for i, element in enumerate(arr):
        print(f"Index {i}: {element}")

def sort_array(arr):
     """Function to sort and print all elements in the array"""
     print("Sorting the array:")
     arr.sort()
     print(arr)
     for i, element in enumerate(arr):
        print(f"Index {i}: {element}")

def insert_array(arr):
     """Function to insert and print all elements in the array"""
     index = int(input("Enter the index to insert at:"))
     value = int(input("Enter the value to insert:"))
     arr.insert(index, value)
     print("After the insertion:")
     for i, element in enumerate(arr):
        print(f"Index {i}: {element}")

def delete_array(arr):
     """Function to delete and print all elements in the array"""
     number = int(input("Enter a number to delete:"))
     if number in arr:
        arr.remove(number)
        print("After the deletion:")
        for i, element in enumerate(arr):
         print(f"Index {i}: {element}")
     else:
        print(f"{number} not found in the array")

def modify_array(arr):
    """Function to modify an element in the array by index"""
    print("Current array:", arr)
    index = int(input("Enter the index of the element you want to modify(0-4): "))

    if 0 <= index < len(arr):
        print(f"Current value at index {index} is {arr[index]}")
        new_value = int(input("Enter the new value: "))
        arr[index] = new_value
        print("Array after modification:")
        for i, element in enumerate(arr):
           print(f"Index {i}: {element}")
    else:
        print(f"Invalid index. Please enter a number between 0 and {len(arr) - 1}.")

def main():
    #initialize an array
    arr = [10, 20, 30, 40, 50]
    print("Original array:", arr)

    while True:
      print("\nMenu:")
      print("1. Traverse array")
      print("2. Reverse array")
      print("3. Sort array")
      print("4. Insert array")
      print("5. Delete array")
      print("6. Modify array")
      print("7. Exit")
      choice = input("Enter your choice (1-7): ")

      if choice == '1':
          traverse_array(arr)
      elif choice == '2':
          reverse_array(arr)
      elif choice == '3':
          sort_array(arr)
      elif choice == '4':
          insert_array(arr)
      elif choice == '5':
          delete_array(arr)
      elif choice == '6':
          modify_array(arr)
      elif choice == '7':
          break
      else:
          print("Invalid choice. Pick a number (1-7)")


if __name__ == "__main__":
  main()
# Out:
# Original array: [10, 20, 30, 40, 50]
#
# Menu:
# 1. Traverse array
# 2. Reverse array
# 3. Sort array
# 4. Insert array
# 5. Delete array
# 6. Modify array
# 7. Exit
# Enter your choice (1-7): 1
# Traversing the array:
# Index 0: 10
# Index 1: 20
# Index 2: 30
# Index 3: 40
# Index 4: 50
#
# Menu:
# 1. Traverse array
# 2. Reverse array
# 3. Sort array
# 4. Insert array
# 5. Delete array
# 6. Modify array
# 7. Exit
# Enter your choice (1-7): 2
# Reversing the array:
# [50, 40, 30, 20, 10]
# Index 0: 10
# Index 1: 20
# Index 2: 30
# Index 3: 40
# Index 4: 50
#
# Menu:
# 1. Traverse array
# 2. Reverse array
# 3. Sort array
# 4. Insert array
# 5. Delete array
# 6. Modify array
# 7. Exit
# Enter your choice (1-7): 3
# Sorting the array:
# [10, 20, 30, 40, 50]
# Index 0: 10
# Index 1: 20
# Index 2: 30
# Index 3: 40
# Index 4: 50
#
# Menu:
# 1. Traverse array
# 2. Reverse array
# 3. Sort array
# 4. Insert array
# 5. Delete array
# 6. Modify array
# 7. Exit
# Enter your choice (1-7): 4
# ...
